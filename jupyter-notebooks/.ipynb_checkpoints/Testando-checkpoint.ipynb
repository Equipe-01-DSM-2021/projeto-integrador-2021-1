# %% [markdown]
# #### Testando análise de dados eleitorais

# %%
print ("""Ano 2020 - Eleição Municipal \n
Ano 2018 - Eleição Federal e Estadual""")
# Out:
# Ano 2020 - Eleição Municipal
#
# Ano 2018 - Eleição Federal e Estadual

# %% [markdown]
# #### Determinando o ano da eleição que será analisada

# %%
eleicao_ano = 2020
print(f"Ano escolhido: {eleicao_ano}")
# Out:
# Ano escolhido: 2020

# %% [markdown]
# #### Importando as bibliotecas Pandas e Plotly, e fazendo as configurações necessárias

# %%
#importando a biblioteca
import pandas as pd
import plotly
import plotly.offline as py
import plotly.graph_objects as go
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Carregando o .csv da eleição de interesse

# %%
if eleicao_ano == 2018:
    filename = r'perfil_eleitorado_2018.csv'
    df = pd.read_csv(filename, delimiter=';', encoding='iso-8859-1',error_bad_lines=False)

elif eleicao_ano == 2020:
    filename = r'perfil_eleitorado_2020.csv'
    df = pd.read_csv(filename, delimiter=';', encoding='iso-8859-1', error_bad_lines=False)

else:
    print("Escolha um ano válido")

# %% [markdown]
# #### Retorna a dimensão do .csv (linhas, colunas)

# %%
df.shape
# Out:
# (4248094, 21)

# %% [markdown]
# #### Retorna o nome das variáveis que estão no cabeçalho do .csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248094 entries, 0 to 4248093
# Data columns (total 21 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   DT_GERACAO                  object
#  1   HH_GERACAO                  object
#  2   ANO_ELEICAO                 int64
#  3   SG_UF                       object
#  4   CD_MUNICIPIO                int64
#  5   NM_MUNICIPIO                object
#  6   CD_MUN_SIT_BIOMETRIA        int64
#  7   DS_MUN_SIT_BIOMETRIA        object
#  8   NR_ZONA                     int64
#  9   CD_GENERO                   int64
#  10  DS_GENERO                   object
#  11  CD_ESTADO_CIVIL             int64
#  12  DS_ESTADO_CIVIL             object
#  13  CD_FAIXA_ETARIA             int64
#  14  DS_FAIXA_ETARIA             object
#  15  CD_GRAU_ESCOLARIDADE        int64
#  16  DS_GRAU_ESCOLARIDADE        object
#  17  QT_ELEITORES_PERFIL         int64
#  18  QT_ELEITORES_BIOMETRIA      int64
# ...

# %% [markdown]
# #### Amostra dos dados do .csv

# %%
df.sample(5)
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 3180846  10/09/2020   23:04:11         2020    PR         75558
# 3359116  10/09/2020   23:04:11         2020    CE         15857
# 2307538  10/09/2020   23:04:11         2020    TO         73350
# 2348570  10/09/2020   23:04:11         2020    PI         11371
# 2410138  10/09/2020   23:04:11         2020    MG         51551
#
#                   NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 3180846               FLORESTA                     0        Sem biometria
# 3359116              MARACANAÚ                     0        Sem biometria
# 2307538   SANTA FÉ DO ARAGUAIA                     0        Sem biometria
# 2348570  NOVO ORIENTE DO PIAUÍ                     0        Sem biometria
# 2410138            SANTA LUZIA                     0        Sem biometria
#
#          NR_ZONA  CD_GENERO  ... CD_ESTADO_CIVIL  DS_ESTADO_CIVIL  \
# ...

# %% [markdown]
# #### Filtrando um subgrupo município

# %%
cidade = df.query('NM_MUNICIPIO == "TAUBATÉ"')

# %% [markdown]
# #### Plot Grau de Escolaridade

# %%
import pandas as pd
# Função que busca quantidade de cada tipo de valor na determinada coluna
# Exemplo, retornar quantos tem ensino superior completo, quantos tem ensino
# medio completo... Retorna um json com o resultado

# EXEMPLO
# SearchForColumn("perfil_eleitorado_2020.csv", "DS_GRAU_ESCOLARIDADE", "SÃO PAULO")
def SearchForColumn(path,  columnToSearch, CityToSearch=None):
    col_list = ["NM_MUNICIPIO", columnToSearch]

    # Lê o csv
    iter_csv = pd.read_csv(
        path, 
        usecols=col_list,
        delimiter=";",
        encoding='iso-8859-1',
        error_bad_lines=False)


    df_result = iter_csv.loc[iter_csv["NM_MUNICIPIO"] == CityToSearch].drop(columns=["NM_MUNICIPIO"], axis=1)

    df_result = df_result.value_counts().rename_axis(columnToSearch).reset_index(name='qnt')

    #df_result = df_result.to_json()

    #df_result = df_result.replace("(", "")
    #df_result = df_result.replace(")", "")
    #df_result = df_result.replace("   ", "")
    #df_result = df_result.replace(",',)", "")
    #df_result = df_result.replace(',":', '":')
    #df_result = df_result.replace("'", "")


    return df_result

path = "perfil_eleitorado_2020.csv"
# TODO Quantidade no dataframe
df = SearchForColumn(path, "DS_GENERO", "SÃO PAULO")

df
# Out:
#        DS_GENERO    qnt
# 0       FEMININO  33860
# 1      MASCULINO  31688
# 2  NÃO INFORMADO   1288

# %%
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-4b1230cc6ec8> in <module>
#       3
#       4 # usando Plotly Express através do backend do Pandas
# ----> 5 fig = df.plot.bar()
#       6 fig.show()
#       7
#
# c:\users\annakks\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1111         other axis represents a measured value.
#    1112         """
# -> 1113         return self(kind="bar", x=x, y=y, **kwargs)
#    1114
#    1115     @Appender(
#
# c:\users\annakks\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     883         # when using another backend, get out of the way
#     884         if plot_backend.__name__ != "pandas.plotting._matplotlib":
# ...

# %% [markdown]
# #### Plot Estado Civil

# %%
px.bar(cidade,x='DS_ESTADO_CIVIL', y='QT_ELEITORES_PERFIL')
# Out:
# <div>                            <div id="f6761c88-67b5-40c3-a855-ab17c0dd6c0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6761c88-67b5-40c3-a855-ab17c0dd6c0e")) {                    Plotly.newPlot(                        "f6761c88-67b5-40c3-a855-ab17c0dd6c0e",                        [{"alignmentgroup": "True", "hovertemplate": "DS_ESTADO_CIVIL=%{x}<br>QT_ELEITORES_PERFIL=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u00daVO", "VI\u0
# ...

# %% [markdown]
# #### Plot Faixa Etária

# %%
cidade.groupby('DS_FAIXA_ETARIA')['QT_ELEITORES_PERFIL'].sum().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='DS_FAIXA_ETARIA'>

# %% [markdown]
# #### Plot Quantidade de eleitores inscritos com nome social

# %%
cidade.groupby('QT_ELEITORES_INC_NM_SOCIAL')['QT_ELEITORES_PERFIL'].sum().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='QT_ELEITORES_INC_NM_SOCIAL'>
